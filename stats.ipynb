# %%
import pandas as pd

# %%
df=pd.read_csv('startup_funding.csv')
df
# Out:
#        SNo        Date       StartupName   IndustryVertical  \
# 0        0  01/08/2017          TouchKin         Technology
# 1        1  02/08/2017           Ethinos         Technology
# 2        2  02/08/2017      Leverage Edu  Consumer Internet
# 3        3  02/08/2017              Zepo  Consumer Internet
# 4        4  02/08/2017      Click2Clinic  Consumer Internet
# ...    ...         ...               ...                ...
# 2367  2367  29/01/2015        Printvenue                NaN
# 2368  2368  29/01/2015          Graphene                NaN
# 2369  2369  30/01/2015    Mad Street Den                NaN
# 2370  2370  30/01/2015         Simplotel                NaN
# 2371  2371  31/01/2015  couponmachine.in                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# ...

# %%
df2=df['AmountInUSD']
df2
# Out:
# 0       1,300,000
# 1             NaN
# 2             NaN
# 3         500,000
# 4         850,000
#           ...
# 2367    4,500,000
# 2368      825,000
# 2369    1,500,000
# 2370          NaN
# 2371      140,000
# Name: AmountInUSD, Length: 2372, dtype: object

# %%
df2.dropna(inplace=True)

# %%
df2
# Out:
# 0       1,300,000
# 3         500,000
# 4         850,000
# 5       1,000,000
# 6       2,600,000
#           ...
# 2366    2,500,000
# 2367    4,500,000
# 2368      825,000
# 2369    1,500,000
# 2371      140,000
# Name: AmountInUSD, Length: 1525, dtype: object

# %%
df2=df2.str.replace(',','')

# %%
df2
# Out:
# 0       1300000
# 3        500000
# 4        850000
# 5       1000000
# 6       2600000
#          ...
# 2366    2500000
# 2367    4500000
# 2368     825000
# 2369    1500000
# 2371     140000
# Name: AmountInUSD, Length: 1525, dtype: object

# %%
#to pick a sample
population=df2
sample_1=population.sample()
sample_1
# Out:
# 1182    400000
# Name: AmountInUSD, dtype: object

# %%
#to get 100 samples
samples=population.sample(100)
samples
# Out:
# 970       148000
# 3         500000
# 5        1000000
# 991       145000
# 765       209000
#           ...
# 2292     1000000
# 883       250000
# 543      5000000
# 2237    15000000
# 675       500000
# Name: AmountInUSD, Length: 100, dtype: object

# %%
#if we want same sample every time
samples=population.sample(100,random_state=1)
samples
# Out:
# 142      4000000
# 1931    16200000
# 309       325000
# 985     25000000
# 439        18000
#           ...
# 1347     3000000
# 1810    30000000
# 1721      150000
# 1913    30000000
# 777      1500000
# Name: AmountInUSD, Length: 100, dtype: object

# %%
#startup from delhi and banglore
city=df[(df['CityLocation']=='Bangalore') | (df['CityLocation']=='bangalore') | (df['CityLocation']=='New Delhi')]
city
# Out:
#        SNo        Date    StartupName            IndustryVertical  \
# 0        0  01/08/2017       TouchKin                  Technology
# 2        2  02/08/2017   Leverage Edu           Consumer Internet
# 5        5  01/07/2017  Billion Loans           Consumer Internet
# 8        8  05/07/2017      Jumbotail                   eCommerce
# 11      11  06/07/2017         Minjar                  Technology
# ...    ...         ...            ...                         ...
# 2190  2190  28/04/2015       Babajobs       Grey collar Job Board
# 2191  2191  28/04/2015   Urban Ladder  Online Furniture ecommerce
# 2196  2196  29/04/2015         Tracxn  Startup Analytics platform
# 2197  2197  29/04/2015           Dazo    Mobile Food Ordering app
# 2198  2198  29/04/2015       Tradelab  Financial Markets Software
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# ...

# %%
population=city['AmountInUSD']
population.dropna(inplace=True)
population
# Out:
# <ipython-input-12-429ace305e26>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population.dropna(inplace=True)
# 0        1,300,000
# 5        1,000,000
# 8        8,500,000
# 13       1,000,000
# 19      18,500,000
#            ...
# 2178    15,000,000
# 2181       500,000
# 2190    10,000,000
# 2196     3,500,000
# 2198       400,000
# Name: AmountInUSD, Length: 617, dtype: object

# %%
population=population.str.replace(',','')
population=pd.to_numeric(population)
samples=population.sample(100,random_state=1)
samples
# Out:
# 1131      450000
# 534      1000000
# 782       675000
# 1567      600000
# 79      12300000
#           ...
# 1273      125000
# 363      1100000
# 1187     1000000
# 1631    10000000
# 2166     1600000
# Name: AmountInUSD, Length: 100, dtype: int64

# %%
pop_max=population.max()
pop_min=population.min()
pop_avg=population.mean()


sample_avg=samples.mean()
sample_min=samples.min()
sample_max=samples.max()

# %%
print(pop_max,"  ",sample_max," ",int(pop_max)-int(sample_max))
print(pop_min,"  ",sample_min," ",int(pop_min)-int(sample_min))
print(pop_avg,"  ",sample_avg," ",pop_avg-sample_avg)
# Out:
# 1400000000    400000000   1000000000
# 18000    30000   -12000
# 18045415.896272287    9087970.0   8957445.896272287
